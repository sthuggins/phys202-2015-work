# %% [markdown]
# # Theory and Practice of Visualization Exercise 1

# %% [markdown]
# ## Imports

# %%
from IPython.display import Image

# %% [markdown]
# ## Graphical excellence and integrity

# %% [markdown]
# Find a data-focused visualization on one of the following websites that is a *positive* example of the principles that Tufte describes in *The Visual Display of Quantitative Information*.
#
# * [Vox](http://www.vox.com/)
# * [Upshot](http://www.nytimes.com/upshot/)
# * [538](http://fivethirtyeight.com/)
# * [BuzzFeed](http://www.buzzfeed.com/)
#
# Upload the image for the visualization to this directory and display the image inline in this notebook.

# %%
# Add your filename and uncomment the following
 #http://fivethirtyeight.com/datalab/african-americans-are-an-outlier-on-indianas-religious-freedom-law/
Image('fuggha.png')

# %% [markdown]
# Describe in detail the ways in which the visualization exhibits graphical *integrity* and *excellence*:

# %% [markdown]
# This graph displays the data involved very well. It presents a wide range of data points and makes the data coherent and easily readable. When looking at this graph, the viewer is prompted to compare data points, in fact, that is the intention of this graph. Not only does this graph show various data points, but it does so in reference to not only the numbers involved, but to the demographics of the providers of the data, in this, the graph reveals data at several levels. Moreover, there are explanations of the data written on the graph itself allowing a viewer to have a much more easy experience when attempting to interpret the information given on the graph.
